# %% [markdown]
# # The Battle of Neighborhoods (Granada)

# %% [markdown]
# Granada is the capital city of the province of Granada, in the autonomous community of Andalusia, Spain. In this notebook we are going to explore, segment, and cluster the towns in the province of Granada.
#
# In the 2005 national census, the population of the city of Granada proper was 236,982, and the population of the entire urban area was estimated to be 472,638, ranking as the 13th-largest urban area of Spain. About 3.3% of the population did not hold Spanish citizenship, the largest number of these people (31%; or 1% of the total population) coming from South America.

# %% [markdown]
# First of all, let's import all required libraries:

# %%
# !conda install -c conda-forge geopy --yes 
# !conda install -c conda-forge folium=0.5.0 --yes
# !conda install lxml --yes

# !pip install geocoder
# !pip install xlrd

import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
import folium # plotting library
import matplotlib.cm as cm
import matplotlib.colors as colors
import json # library to handle JSON files
import geocoder # to get coordinates

from pandas.io.json import json_normalize # tranforming json file into a pandas dataframe library
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
from IPython.display import Image # libraries for displaying images
from IPython.core.display import HTML # libraries for displaying images
from sklearn.cluster import KMeans # import k-means from clustering stage
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     scikit-learn-0.20.1        |   py36h22eb022_0         5.7 MB
#     liblapack-3.8.0            |      11_openblas          10 KB  conda-forge
#     numpy-1.18.1               |   py36h95a1406_0         5.2 MB  conda-forge
#     liblapacke-3.8.0           |      11_openblas          10 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     libopenblas-0.3.6          |       h5a2b251_2         7.7 MB
#     scipy-1.4.1                |   py36h921218d_0        18.9 MB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     libcblas-3.8.0             |      11_openblas          10 KB  conda-forge
#     libblas-3.8.0              |      11_openblas          10 KB  conda-forge
#     blas-2.11                  |         openblas          10 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        37.9 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0                              conda-forge
#     geopy:         1.21.0-py_0                            conda-forge
#     libblas:       3.8.0-11_openblas                      conda-forge
#     libcblas:      3.8.0-11_openblas                      conda-forge
#     liblapack:     3.8.0-11_openblas                      conda-forge
#     liblapacke:    3.8.0-11_openblas                      conda-forge
#     libopenblas:   0.3.6-h5a2b251_2
#
# The following packages will be UPDATED:
#
#     blas:          1.1-openblas                           conda-forge --> 2.11-openblas         conda-forge
#     certifi:       2019.9.11-py36_0                       conda-forge --> 2019.11.28-py36_0     conda-forge
#     numpy:         1.16.2-py36_blas_openblash1522bff_0    conda-forge [blas_openblas] --> 1.18.1-py36h95a1406_0 conda-forge
#     scipy:         1.2.1-py36_blas_openblash1522bff_0     conda-forge [blas_openblas] --> 1.4.1-py36h921218d_0  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     scikit-learn:  0.20.1-py36_blas_openblashebff5e3_1200 conda-forge [blas_openblas] --> 0.20.1-py36h22eb022_0
#
#
# Downloading and Extracting Packages
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# scikit-learn-0.20.1  | 5.7 MB    | ##################################### | 100%
# liblapack-3.8.0      | 10 KB     | ##################################### | 100%
# numpy-1.18.1         | 5.2 MB    | ##################################### | 100%
# liblapacke-3.8.0     | 10 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# libopenblas-0.3.6    | 7.7 MB    | ##################################### | 100%
# scipy-1.4.1          | 18.9 MB   | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# libcblas-3.8.0       | 10 KB     | ##################################### | 100%
# libblas-3.8.0        | 10 KB     | ##################################### | 100%
# blas-2.11            | 10 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - lxml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     scipy-1.4.1                |   py36habc2bb6_0        18.8 MB
#     openssl-1.1.1d             |       h7b6447c_4         3.7 MB
#     numpy-1.18.1               |   py36h94c655d_0           5 KB
#     lxml-4.3.0                 |   py36hefd8a0e_0         1.5 MB
#     certifi-2019.11.28         |           py36_0         156 KB
#     numpy-base-1.18.1          |   py36h2f8d375_1         5.2 MB
#     ------------------------------------------------------------
#                                            Total:        29.5 MB
#
# The following packages will be UPDATED:
#
#     certifi:    2019.11.28-py36_0     conda-forge --> 2019.11.28-py36_0
#     lxml:       4.2.5-py37hefd8a0e_0              --> 4.3.0-py36hefd8a0e_0
#     numpy:      1.18.1-py36h95a1406_0 conda-forge --> 1.18.1-py36h94c655d_0
#     numpy-base: 1.15.1-py37h81de0dd_0             --> 1.18.1-py36h2f8d375_1
#     openssl:    1.1.1d-h516909a_0     conda-forge --> 1.1.1d-h7b6447c_4
#     scipy:      1.4.1-py36h921218d_0  conda-forge --> 1.4.1-py36habc2bb6_0
#
#
# Downloading and Extracting Packages
# scipy-1.4.1          | 18.8 MB   | ##################################### | 100%
# openssl-1.1.1d       | 3.7 MB    | ##################################### | 100%
# numpy-1.18.1         | 5 KB      | ##################################### | 100%
# lxml-4.3.0           | 1.5 MB    | ##################################### | 100%
# certifi-2019.11.28   | 156 KB    | ##################################### | 100%
# numpy-base-1.18.1    | 5.2 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 5.0MB/s ta 0:00:011
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (2.22.0)
# Collecting future (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#      |████████████████████████████████| 829kB 28.1MB/s eta 0:00:01
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (1.13.0)
# Collecting click (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/fa/37/45185cb5abbc30d7257104c434fe0b07e5a195a6847506c074527aa599ec/Click-7.0-py2.py3-none-any.whl (81kB)
#      |████████████████████████████████| 81kB 5.5MB/s eta 0:00:011
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ratelim->geocoder) (4.4.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (1.25.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2019.11.28)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# Installing collected packages: ratelim, future, click, geocoder
# Successfully installed click-7.0 future-0.18.2 geocoder-1.38.1 ratelim-0.1.6
# Collecting xlrd
#   Downloading https://files.pythonhosted.org/packages/b0/16/63576a1a001752e34bf8ea62e367997530dc553b689356b9879339cf45a4/xlrd-1.2.0-py2.py3-none-any.whl (103kB)
#      |████████████████████████████████| 112kB 3.0MB/s eta 0:00:01
# Installing collected packages: xlrd
# Successfully installed xlrd-1.2.0

# %%
def get_latlng(NBH):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Granada, Granada, Spain'.format(NBH))
        lat_lng_coords = g.latlng
    return lat_lng_coords

# %% [markdown]
# ## Data Collection

# %% [markdown]
# #### Municipalties in the province of Granada

# %% [markdown]
# Get municipalties' information from the official website of Junta de Andalucía, which is the entity responsible for gathering all the information in Andalusia.

# %%
dfM0 = pd.read_excel('https://www.juntadeandalucia.es/institutodeestadisticaycartografia/sima/datos/smex99.xls',skiprows=9,header=1)

# %% [markdown]
# Separate latitude and longitude in different columns

# %%
dfM0.insert(3,"Latitud" ,dfM0["Coordenadas del núcleo principal. 2019"].str.split(",", n = 1, expand = True)[0].astype(float))
dfM0.insert(4,"Longitud",dfM0["Coordenadas del núcleo principal. 2019"].str.split(",", n = 1, expand = True)[1].astype(float))
dfM0.drop(columns =["Coordenadas del núcleo principal. 2019"], inplace = True)

# %% [markdown]
# We can see there are a huge amount of data in this Data Frame

# %%
list(dfM0)
# Out:
# ['Provincia',
#  'CodMun',
#  'Municipio',
#  'Latitud',
#  'Longitud',
#  'Extensión superficial. 2019',
#  'Perímetro. 2019',
#  'Altitud sobre el nivel del mar. 2019',
#  'Número de núcleos que componen el municipio. 2018',
#  'Distancia a la capital. 2019',
#  'Población total. 2018',
#  'Población. Hombres. 2018',
#  'Población. Mujeres. 2018',
#  'Población en núcleos. 2018',
#  'Población en diseminados. 2018',
#  'Edad media. 2018',
#  'Porcentaje de población menor de 20 años. 2018',
#  'Porcentaje de población mayor de 65 años. 2018',
#  'Incremento relativo de la población en diez años. 2018',
#  'Número de extranjeros. 2018',
#  'Principal procedencia de los extranjeros residentes. 2018',
#  'Porcentaje que representa respecto total de extranjeros. 2018',
#  'Emigraciones. 2017',
#  'Inmigraciones. 2017',
#  'Nacimientos. 2017',
#  'Defunciones. 2017',
#  'Matrimonios. 2017',
#  'Centros de Infantil. 2016',
#  'Centros de Primaria. 2016',
#  'Centros de Enseñanza Secundaria Obligatoria. 2016',
#  'Centros  de Bachillerato. 2016',
#  'Centros  C.F. de Grado Medio. 2016',
#  'Centros  C.F. de Grado Superior. 2016',
#  'Centros de educación de adultos. 2016',
#  'Bibliotecas públicas. 2016',
#  'Centros de salud. 2016',
#  'Consultorios. 2016',
#  'Viviendas familiares principales. 2011',
#  'Transacciones inmobiliarias. Vivienda nueva. 2017',
#  'Transacciones inmobiliarias. Vivienda segunda mano. 2017',
#  'Número de pantallas de cine. 2018',
#  'Elecciones Generales. Censo electoral. 2019',
#  'Elecciones Generales. Abstenciones. 2019',
#  'Elecciones Generales. Fuerza política 1. 2019',
#  'Elecciones Generales. Fuerza política 2. 2019',
#  'Elecciones Generales. Fuerza política 3. 2019',
#  'Elecciones Generales. Fuerza política 4. 2019',
#  'Elecciones Generales. Fuerza política 5. 2019',
#  'Elecciones al Parlamento. Censo electoral. 2018',
#  'Elecciones al Parlamento. Abstenciones. 2018',
#  'Elecciones al Parlamento. Fuerza política 1. 2018',
#  'Elecciones al Parlamento. Fuerza política 2. 2018',
#  'Elecciones al Parlamento. Fuerza política 3. 2018',
#  'Elecciones al Parlamento. Fuerza política 4. 2018',
#  'Elecciones al Parlamento. Fuerza política 5. 2018',
#  'Elecciones Locales. Censo electoral. 2015',
#  'Elecciones Locales. Abstenciones. 2015',
#  'Elecciones Locales. Fuerza política 1. 2015',
#  'Elecciones Locales. Fuerza política 2. 2015',
#  'Elecciones Locales. Fuerza política 3. 2015',
#  'Elecciones Locales. Fuerza política 4. 2015',
#  'Elecciones Locales. Fuerza política 5. 2015',
#  'Superficie. 2017',
#  'Principal cultivo de regadío. 2017',
#  'Principal cultivo de regadío: Has. 2017',
#  'Principal cultivo de secano. 2017',
#  'Principal cultivo de secano: Has. 2017',
#  'Superficie. 2017.1',
#  'Principal cultivo de regadío. 2017.1',
#  'Principal cultivo de regadío: Has. 2017.1',
#  'Principal cultivo de secano. 2017.1',
#  'Principal cultivo de secano: Has. 2017.1',
#  'Sin asalariados. 2017',
#  'Hasta 5 asalariados. 2017',
#  'Entre 6 y 19 asalariados. 2017',
#  'De 20 y más asalariados. 2017',
#  'Total establecimientos. 2017',
#  'Actividad 1. 2017',
#  'Actividad 2. 2017',
#  'Actividad 3. 2017',
#  'Actividad 4. 2017',
#  'Actividad 5. 2017',
#  'Vehículos turismos. 2017',
#  'Autorizaciones de transporte: taxis. 2017',
#  'Autorizaciones de transporte: mercancías. 2017',
#  'Autorizaciones de transporte: viajeros. 2017',
#  'Vehículos matriculados. 2017',
#  'Vehículos turismos matriculados. 2017',
#  'Número de cooperativas creadas. 2015',
#  'Oficinas de entidades de crédito. 2017',
#  'Consumo de energía eléctrica (Endesa). 2017',
#  'Consumo de energía eléctrica residencial (Endesa). 2017',
#  'Hoteles. 2017',
#  'Hostales y pensiones. 2017',
#  'Plazas en hoteles. 2017',
#  'Plazas en hostales y pensiones. 2017',
#  'Paro registrado. Mujeres. 2018',
#  'Paro registrado. Hombres. 2018',
#  'Paro registrado. Extranjeros. 2018',
#  'Tasa municipal de desempleo. 2018',
#  'Contratos registrados. Mujeres. 2018',
#  'Contratos registrados. Hombres. 2018',
#  'Contratos registrados. Indefinidos. 2018',
#  'Contratos registrados. Temporales. 2018',
#  'Contratos registrados. Extranjeros. 2018',
#  'Trabajadores eventuales agrarios subsidiados. Mujeres. 2018',
#  'Trabajadores eventuales agrarios subsidiados. Hombres. 2018',
#  'Presupuesto liquidado de ingresos. 2016',
#  'Presupuesto liquidado de gastos. 2016',
#  'Ingresos por habitante. 2016',
#  'Gastos por habitante. 2016',
#  'Número de declaraciones. 2016',
#  'Renta neta media declarada. 2016',
#  'IBI de naturaleza urbana. Número de recibos. 2017',
#  'IBI de naturaleza rústica. Número titulares catastrales. 2017',
#  'Número de parcelas catastrales: Solares. 2017',
#  'Número de parcelas catastrales: Parcelas edificadas. 2017',
#  'Situaciones de alta en actividades empresariales. 2016',
#  'Situaciones de alta en actividades profesionales. 2016',
#  'Situaciones de alta en actividades artísticas. 2016']

# %% [markdown]
# We are going to work only with a few columns

# %%
dfM1 = dfM0[['Provincia','Municipio','Latitud','Longitud']]

# %% [markdown]
# Print the number of provinces and municipalties

# %%
print('The dataframe has {} provinces and {} municipalties.'.format(len(dfM0['Provincia'].unique()),len(dfM0['Municipio'].unique())))
# Out:
# The dataframe has 8 provinces and 785 municipalties.

# %% [markdown]
# Let's see the name of the provinces and how many municipalties there are in each one

# %%
dfM1.groupby('Provincia').count().iloc[:,0:1].sort_values(by='Municipio',ascending=False).reset_index()
# Out:
#   Provincia  Municipio
# 0   Granada        174
# 1   Sevilla        106
# 2   Almería        103
# 3    Málaga        103
# 4      Jaén         97
# 5    Huelva         80
# 6   Córdoba         77
# 7     Cádiz         45

# %% [markdown]
# As we see, Granada is by far the province with more municipalties in Andalusia.

# %% [markdown]
# Now let's select only the towns in the province of Granada:

# %%
dfM2 = dfM1[dfM1['Provincia'].str.contains("Granada")].reset_index(drop=True)
dfM2.head()
# Out:
#   Provincia    Municipio    Latitud  Longitud
# 0   Granada       Agrón   37.030104 -3.829328
# 1   Granada  Alamedilla   37.581725 -3.244387
# 2   Granada    Albolote   37.230548 -3.657339
# 3   Granada    Albondón   36.827281 -3.211111
# 4   Granada     Albuñán   37.227319 -3.133350

# %% [markdown]
# #### Neighborhoods in Granada

# %% [markdown]
# Get the neighborhood's information

# %%
dfN0 = pd.read_html('https://es.wikipedia.org/wiki/Distritos_de_Granada')[0].drop(columns='Ubicación').replace({" y ":", ","-":", ",r'\.': ''},regex=True)

# %% [markdown]
# Separate the neighborhoods into different cells

# %%
dfN1 = pd.DataFrame([sub.split(",") for sub in dfN0.Barrios])

# %% [markdown]
# Restructure the in two columns: District and Neighborhood

# %%
data=[]
for i in range(0, 8):
    for j in range(0, 8):
        data.append([dfN0.Distrito[j],dfN1[i][j]])

# %% [markdown]
# Create a DataFrame with the info above

# %%
dfN2 = pd.DataFrame(data,columns=['Distrito','Barrio'])

# %% [markdown]
# Remove null values

# %%
dfN3 = dfN2[dfN2["Barrio"].notnull()].reset_index(drop=True)
print('Granada has {} neighborhoods.'.format(len(dfN3['Barrio'].unique())))
# Out:
# Granada has 40 neighborhoods.

# %% [markdown]
# Create a list with the coordinates of every neighborhood

# %%
LL = pd.DataFrame([get_latlng(NBH) for NBH in dfN3["Barrio"].tolist()], columns=['Latitude', 'Longitude'])

# %% [markdown]
# Add coordinates to the DataFrame

# %%
dfN3['Latitud' ] = LL['Latitude' ]
dfN3['Longitud'] = LL['Longitude']
dfN3.head()
# Out:
#    Distrito            Barrio    Latitud  Longitud
# 0  Albayzín          Albaicín  37.183580 -3.592530
# 1     Beiro  Joaquina Eguaras  37.202110 -3.611120
# 2    Centro            Centro  37.176520 -3.603950
# 3     Chana         Angustias  37.202432 -3.609718
# 4     Genil       Bola de Oro  37.162800 -3.582980

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# Get the coordinates of Granada

# %%
location = Nominatim(user_agent = "foursquare_agent").geocode('Granada, Granada, Spain')

# %%
map = folium.Map(location = [location.latitude, location.longitude], zoom_start = 13)

for lat, lng, M in zip(dfM2.Latitud, dfM2.Longitud, dfM2.Municipio):
    folium.features.CircleMarker([lat, lng],radius=5.0,color='green',popup=M).add_to(map)
for lat, lng, N in zip(dfN3.Latitud, dfN3.Longitud, dfN3.Barrio):
    folium.features.CircleMarker([lat, lng],radius=2.5,color='blue' ,popup=N).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now, let's concentrate in the neighboorhoods of Granada (blue points)

# %% [markdown]
# ## Getting Venues

# %% [markdown]
# Define FourSquare Credentials

# %%
ID  = '5BE1CFT1DAZS0QY4L02YFE3312POUPPMMW3PTEMNBYU3UNPC'
sec = 'TTCGHPU30N3LWFLLCHWMOSDHQ1BBFVU2I53NRYUJNEZR3X0F'
ver = '20180604'

# %% [markdown]
# Create the DataFrame of Venues

# %%
lim = 100; rad = 500

venues_list = []

for N, lat, lon in zip(dfN3['Barrio'],dfN3['Latitud'],dfN3['Longitud']):
                    
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(ID,sec,ver,lat,lon,rad,lim)
    results = requests.get(url).json()["response"]['groups'][0]['items']
    venues_list.append([(N,lat,lon,v['venue']['name'],v['venue']['location']['lat'],v['venue']['location']['lng'], v['venue']['categories'][0]['name']) for v in results])

dfV = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
dfV.columns = ['Neighborhood','NLat','NLon','Venue','VLat','VLon','VCat']

print('There are {} venues'.format(dfV.shape[0]))
# Out:
# There are 1055 venues

# %% [markdown]
# Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(dfV['VCat'].unique())))
# Out:
# There are 108 uniques categories.

# %% [markdown]
# Let's homogeneize the categories

# %%
dfV.loc[dfV['VCat'].str.contains("Restaurant"),'VCat'] = 'Restaurant'
dfV.loc[dfV['VCat'].str.contains("Bar"       ),'VCat'] = 'Bar'
dfV.loc[dfV['VCat'].str.contains("Cafe"      ),'VCat'] = 'Café'
dfV.loc[dfV['VCat'].str.contains("Stadium"   ),'VCat'] = 'Stadium'
dfV.loc[dfV['VCat'].str.contains("Gym"       ),'VCat'] = 'Gym'
dfV.loc[dfV['VCat'].str.contains("Shop"      ),'VCat'] = 'Shop'
dfV.loc[dfV['VCat'].str.contains("Pub"       ),'VCat'] = 'Pub'
dfV.loc[dfV['VCat'].str.contains("Store"     ),'VCat'] = 'Store'

print('There are {} homogeneized categories.'.format(len(dfV['VCat'].unique())))
# Out:
# There are 61 homogeneized categories.

# %% [markdown]
# Number of venues by neighborhood

# %%
dfV.groupby('Neighborhood').count().iloc[:,0:1].sort_values(by='NLat',ascending=False).reset_index()
# Out:
#                Neighborhood  NLat
# 0                Sacromonte   100
# 1                    Encina    87
# 2                San Matías    76
# 3                    Centro    68
# 4                   Realejo    60
# 5                  Vergeles    55
# 6                   Figares    54
# 7          Lancha del Genil    50
# 8            Plaza de Toros    48
# 9                  Sagrario    47
# 10                 Doctores    47
# 11               San Lázaro    43
# 12          Camino de Ronda    37
# 13                 Albaicín    33
# 14               Mirasierra    31
# 15            San Ildefonso    31
# 16                Pajaritos    22
# 17         Joaquina Eguaras    19
# 18    Camino de los Neveros    18
# 19                Angustias    16
# 20                Cervantes    14
# 21                  La Cruz     9
# 22     San Francisco Javier     9
# 23                 Rosaleda     8
# 24   Carretera de la Sierra     8
# 25                    Chana     7
# 26     Cerrillo de Maracena     6
# 27                  Castaño     6
# 28              Haza Grande     6
# 29                   Zaidín     5
# 30                   La Paz     5
# 31       Casería de Montijo     5
# 32                  Cartuja     5
# 33              Bola de Oro     4
# 34                Bobadilla     4
# 35              Campo Verde     4
# 36     Parque Nueva Granada     4
# 37               Almanjáyar     2
# 38                Rey Badis     1
# 39                El Fargue     1

# %% [markdown]
# Number of neighborhoods by venue category

# %%
dfV.groupby('VCat').count().iloc[:,0:1].sort_values(by='Neighborhood',ascending=False).reset_index()
# Out:
#                 VCat  Neighborhood
# 0         Restaurant           364
# 1               Shop            97
# 2                Bar            76
# 3              Hotel            68
# 4              Plaza            63
# ..               ...           ...
# 56          Bus Line             1
# 57  Botanical Garden             1
# 58          Tea Room             1
# 59         BBQ Joint             1
# 60    Sandwich Place             1
#
# [61 rows x 2 columns]

# %% [markdown]
# #### One Hot Encoding

# %%
OHE = pd.get_dummies(dfV[['VCat']], prefix="", prefix_sep="") # one hot encoding
OHE['Neighborhood'] = dfV['Neighborhood'] # add neighborhood column back to dataframe
fixcols = [OHE.columns[-1]] + list(OHE.columns[:-1]) # move neighborhood column to the first column
OHE = OHE[fixcols]

# %% [markdown]
# Group rows by town and by taking the mean of the frequency of occurrence of each category

# %%
OHG = OHE.groupby('Neighborhood').mean().reset_index()
OHg = OHG.drop('Neighborhood', 1)
OHg.shape
# Out:
# (40, 61)

# %% [markdown]
# The matrix we are going to use for clustering has 40 neighborhoods and 60 unique categories

# %% [markdown]
# ## Clustering

# %% [markdown]
# Run k-means to cluster the Granada towns into clusters

# %%
K = 5

kmeans = KMeans(n_clusters = K, random_state=0).fit(OHg) # run k-means clustering

ntv = 10

indicators = ['st', 'nd', 'rd']

columns = ['Neighborhood']
for ind in np.arange(ntv):
    try:
        columns.append('{}{}'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th'.format(ind+1))
        
NVS = pd.DataFrame(columns=columns)

NVS['Neighborhood'] = OHG['Neighborhood']

for ind in np.arange(OHG.shape[0]):
    NVS.iloc[ind, 1:] = OHG.iloc[ind, :].iloc[1:].sort_values(ascending=False).index.values[0:ntv]
    
NVS.insert(0,'Cluster',kmeans.labels_) # add clustering labels

dfN4 = dfN3.join(NVS.set_index('Neighborhood'), on='Barrio') # merge grouped with data to add latitude/longitude for each neighborhood
dfN5 = dfN4[dfN4['Cluster'].notnull()].reset_index(drop = True)

# %% [markdown]
# Create the map

# %%
map_clusters = folium.Map(location=[lat,lon], zoom_start=13)

# set color scheme for the clusters
x = np.arange(K)
ys = [i + x + (i*x)**2 for i in range(K)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(dfN5['Latitud'], dfN5['Longitud'], dfN5['Barrio'], dfN5['Cluster']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Analysis of clusters

# %% [markdown]
# Sumary of categories by cluster

# %%
df1 = dfV.merge(NVS.iloc[:,0:2], on='Neighborhood', how='left')
df2 = df1[['Venue','VCat','Cluster']]
df3 = df2.pivot_table(index='VCat',columns='Cluster',aggfunc='count',fill_value=0)
df3
# Out:
#                      Venue
# Cluster                  0  1  2  3   4
# VCat
# Art Museum               2  0  0  0   0
# Arts & Entertainment     0  0  0  0   1
# BBQ Joint                1  0  0  0   0
# Bar                     13  1  0  3  59
# Bed & Breakfast          1  0  0  0   6
# ...                    ... .. .. ..  ..
# Store                   13  0  0  0  17
# Supermarket              0  0  0  0   6
# Tea Room                 0  0  0  0   1
# Theater                  2  0  0  0   6
# Winery                   0  0  0  0   2
#
# [61 rows x 5 columns]

# %% [markdown]
# Now let's examine the clusters:

# %% [markdown]
# **Cluster 0**

# %%
dfN5.loc[dfN5['Cluster'] == 1-1, dfN5.columns[[1] + list(range(5, dfN5.shape[1]))]]
# Out:
#                     Barrio         1st            2nd           3rd  \
# 1         Joaquina Eguaras  Restaurant    Bus Station         Store
# 3                Angustias        Park           Café   Bus Station
# 12   Camino de los Neveros       Store           Shop    Restaurant
# 15                Vergeles  Restaurant  Historic Site          Shop
# 16             Haza Grande    Pharmacy        Brewery         Plaza
# 18                 Realejo  Restaurant  Historic Site          Shop
# 26               Bobadilla        Shop          Store  Intersection
# 28      Casería de Montijo        Shop         Garden           Bar
# 35                  La Paz        Shop          Store         Plaza
# 39           San Ildefonso        Café          Hotel    Restaurant
#
#            4th           5th             6th                     7th  \
# 1         Park          Shop           Plaza              Campground
# 3        Store          Shop      Restaurant                   Hotel
# 12        Park           Gym   Movie Theater                Boutique
# 15         Bar         Plaza           Hotel                  Bistro
# 16     Stadium         Hotel      Restaurant  College Residence Hall
# 18         Bar         Hotel           Plaza                  Bistro
# 26   Rock Club  Concert Hall          Castle                  Church
# 28  Restaurant          Café    Concert Hall                  Castle
# 35        Park          Café           Diner           Deli / Bodega
# 39       Plaza          Shop  Scenic Lookout           Historic Site
#
#                 8th                     9th                    10th
# 1          Boutique                    Café                Bus Line
# 3    Breakfast Spot                   Plaza                Boutique
# 12  College Library              Campground                  Castle
# 15           Garden   Performing Arts Venue                    Café
# 16           Castle                  Church         College Library
# 18           Garden   Performing Arts Venue                    Café
# 26  College Library  College Residence Hall                  Winery
# 28           Church         College Library  College Residence Hall
# 35     Dance Studio             Dry Cleaner            Concert Hall
# 39           Garden           Deli / Bodega            Dance Studio

# %% [markdown]
# **Cluster 1**

# %%
dfN5.loc[dfN5['Cluster'] == 2-1, dfN5.columns[[1] + list(range(5, dfN5.shape[1]))]]
# Out:
#         Barrio         1st     2nd     3rd         4th        5th     6th  \
# 8    El Fargue  Restaurant  Winery    Café   Gastropub     Garden    Food
# 22    Rosaleda  Restaurant     Bar  Winery  Campground  Gastropub  Garden
#
#             7th          8th            9th           10th
# 8   Dry Cleaner        Diner  Deli / Bodega   Dance Studio
# 22         Food  Dry Cleaner          Diner  Deli / Bodega

# %% [markdown]
# **Cluster 2**

# %%
dfN5.loc[dfN5['Cluster'] == 3-1, dfN5.columns[[1] + list(range(5, dfN5.shape[1]))]]
# Out:
#         Barrio   1st     2nd   3rd        4th     5th   6th          7th  \
# 38   Rey Badis  Shop  Winery  Café  Gastropub  Garden  Food  Dry Cleaner
#
#       8th            9th          10th
# 38  Diner  Deli / Bodega  Dance Studio

# %% [markdown]
# **Cluster 3**

# %%
dfN5.loc[dfN5['Cluster'] == 4-1, dfN5.columns[[1] + list(range(5, dfN5.shape[1]))]]
# Out:
#                    Barrio  1st             2nd                     3rd  \
# 5              Almanjáyar  Bar  Breakfast Spot                  Winery
# 21                Cartuja  Gym             Bar                    Lake
# 30   Cerrillo de Maracena  Gym         Stadium          Breakfast Spot
# 32   Parque Nueva Granada  Gym            Lake  College Residence Hall
#
#                        4th                           5th        6th  \
# 5               Campground                     Gastropub     Garden
# 21  College Residence Hall                          Park     Castle
# 30                    Park                         Diner        Bar
# 32                    Park  General College & University  Gastropub
#
#           7th          8th          9th           10th
# 5        Food  Dry Cleaner        Diner  Deli / Bodega
# 21  Gastropub       Garden         Food    Dry Cleaner
# 30       Food  Dry Cleaner       Garden  Deli / Bodega
# 32     Garden         Food  Dry Cleaner          Diner

# %% [markdown]
# **Cluster 4**

# %%
dfN5.loc[dfN5['Cluster'] == 5-1, dfN5.columns[[1] + list(range(5, dfN5.shape[1]))]]
# Out:
#                      Barrio         1st             2nd          3rd  \
# 0                  Albaicín  Restaurant  Scenic Lookout         Café
# 2                    Centro  Restaurant            Shop        Hotel
# 4               Bola de Oro  Restaurant             Bar      Stadium
# 6           Camino de Ronda  Restaurant           Hotel  Pizza Place
# 7                    Zaidín  Restaurant         Theater  Supermarket
# 9                   La Cruz  Restaurant     Pizza Place          Gym
# 10                 Sagrario  Restaurant           Hotel         Shop
# 11                    Chana  Restaurant     Pizza Place      Stadium
# 13              Campo Verde        Café     Supermarket   Restaurant
# 14                  Figares  Restaurant           Hotel         Shop
# 17                Pajaritos  Restaurant            Café         Shop
# 19                   Encina  Restaurant            Shop        Plaza
# 20   Carretera de la Sierra  Restaurant        Pharmacy      Stadium
# 23               Sacromonte  Restaurant            Shop          Bar
# 24           Plaza de Toros  Restaurant            Café          Bar
# 25               San Matías  Restaurant            Shop        Plaza
# 27                  Castaño  Restaurant     Pizza Place      Stadium
# 29                 Doctores  Restaurant           Hotel         Shop
# 31               Mirasierra  Restaurant     Pizza Place         Café
# 33               San Lázaro  Restaurant             Bar         Café
# 34                Cervantes  Restaurant             Bar  Pizza Place
# 36     San Francisco Javier  Restaurant     Pizza Place         Café
# 37         Lancha del Genil  Restaurant           Plaza          Bar
#
#                4th             5th                     6th              7th  \
# 0            Plaza           Hotel           Historic Site           Hostel
# 2             Café             Bar                   Plaza  Bed & Breakfast
# 4           Winery    Concert Hall                  Castle           Church
# 6            Store             Bar                     Pub             Shop
# 7           Winery    Concert Hall                  Castle           Church
# 9             Café      Campground                   Store      Dry Cleaner
# 10             Bar            Café                    Park              Pub
# 11  Breakfast Spot            Park                  Winery  College Library
# 13          Winery          Garden                    Food      Dry Cleaner
# 14           Diner     Pizza Place                     Gym              Bar
# 17           Plaza  Breakfast Spot                  Hostel        Gastropub
# 19             Bar           Hotel             Pizza Place            Store
# 20           Hotel  Scenic Lookout                   Diner    Deli / Bodega
# 23           Plaza           Hotel                    Café           Bistro
# 24           Plaza           Hotel             Pizza Place              Pub
# 25             Bar           Hotel                  Bistro            Store
# 27  Breakfast Spot          Winery  College Residence Hall           Castle
# 29             Bar            Café                    Park              Pub
# 31             Bar           Store                 Stadium            Plaza
# 33           Hotel           Plaza             Pizza Place      Supermarket
# 34            Café        Pharmacy                   Store   Breakfast Spot
# 36     Supermarket           Store  College Residence Hall       Campground
# 37            Shop          Bistro                    Park          Theater
#
#                 8th                     9th                          10th
# 0      Dance Studio                  Garden                       Brewery
# 2               Pub             Pizza Place                        Hostel
# 4   College Library  College Residence Hall                 Deli / Bodega
# 6       Dry Cleaner          Sandwich Place                     Bookstore
# 7   College Library  College Residence Hall                 Deli / Bodega
# 9             Diner           Deli / Bodega                  Concert Hall
# 10              Gym                  Hostel                   Bus Station
# 11       Campground                  Castle                        Church
# 13            Diner           Deli / Bodega                  Dance Studio
# 14             Café               Nightclub  General College & University
# 17              Bar                     Gym                   Supermarket
# 19           Bistro          History Museum                         Diner
# 20      Dry Cleaner            Dance Studio                   Bus Station
# 23  Bed & Breakfast                     Pub                   Pizza Place
# 24      Supermarket             Music Venue                       Brewery
# 25   History Museum                    Café                           Pub
# 27           Church         College Library                  Concert Hall
# 29              Gym                  Hostel                   Bus Station
# 31           Winery                  Castle                        Church
# 33        Gastropub             Music Venue                       Brewery
# 34  College Library                  Castle                        Church
# 36           Castle                  Church               College Library
# 37            Hotel          History Museum                          Café
