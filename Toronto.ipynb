# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# Explore, segment, and cluster the neighborhoods in the city of Toronto.

# %% [markdown]
# #### Import all required libraries

# %%
#!conda install -c conda-forge geopy --yes 
#!conda install -c conda-forge folium=0.5.0 --yes
#!conda install lxml --yes

import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
import folium # plotting library
import matplotlib.cm as cm
import matplotlib.colors as colors

from pandas.io.json import json_normalize # tranforming json file into a pandas dataframe library
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
from IPython.display import Image # libraries for displaying images
from IPython.core.display import HTML # libraries for displaying images
from sklearn.cluster import KMeans # import k-means from clustering stage

# %% [markdown]
# ## **PART 1**

# %% [markdown]
# #### Scrap data from Wikipedia page into a DataFrame

# %% [markdown]
# Read the table with pandas and rename column titles

# %%
df0 = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
df0.rename(index = str, columns = {"Postcode": "PostalCode", "Neighbourhood":"Neighborhood"}, inplace = True)

# %% [markdown]
# Manage "Not assigned" values

# %%
df1 = df0[df0.Borough != "Not assigned"].reset_index(drop = True) # Drop "Not assigned" boroughs
df1.Neighborhood[df1['Neighborhood'] == 'Not assigned'] = df1.Borough[df1['Neighborhood'] == 'Not assigned'] # Rename "Not assigned" neighborhoods

# %% [markdown]
# Group neighborhoods in the same borough

# %%
df2 = df1.groupby(["PostalCode", "Borough"], as_index = False).agg(lambda x: ", ".join(x))
df2.shape
# Out:
# (103, 3)

# %% [markdown]
# Check whether it is the same as required by the question

# %%
dft = pd.DataFrame(columns=["PostalCode", "Borough", "Neighborhood"])

for pc in ["M5G", "M2H", "M4B", "M1J", "M4G", "M4M", "M1R", "M9V", "M9L", "M5V", "M1B", "M5A"]:
    dft = dft.append(df2[df2["PostalCode"]==pc], ignore_index=True)
    
dft
# Out:
#    PostalCode           Borough  \
# 0         M5G  Downtown Toronto
# 1         M2H        North York
# 2         M4B         East York
# 3         M1J       Scarborough
# 4         M4G         East York
# 5         M4M      East Toronto
# 6         M1R       Scarborough
# 7         M9V         Etobicoke
# 8         M9L        North York
# 9         M5V  Downtown Toronto
# 10        M1B       Scarborough
# 11        M5A  Downtown Toronto
#
#                                          Neighborhood
# 0                                  Central Bay Street
# 1                                   Hillcrest Village
# 2                     Woodbine Gardens, Parkview Hill
# 3                                 Scarborough Village
# 4                                             Leaside
# 5                                     Studio District
# 6                                   Maryvale, Wexford
# 7   Albion Gardens, Beaumond Heights, Humbergate, ...
# 8                                       Humber Summit
# 9   CN Tower, Bathurst Quay, Island airport, Harbo...
# 10                                     Rouge, Malvern
# 11                                       Harbourfront

# %% [markdown]
# As it can be observed, Regent Park is no longer in the M5A postal code (check at Wikipedia)

# %% [markdown]
# ## **PART 2**

# %% [markdown]
# #### Add geographical coordinates to the DataFrame

# %% [markdown]
# Import data with coordinates and rename

# %%
dfc = pd.read_csv('https://cocl.us/Geospatial_data')
dfc.rename(index = str, columns = {"Postal Code": "PostalCode"}, inplace = True)

# %% [markdown]
# Join the two data frames

# %%
df3 = df2.join(dfc.set_index('PostalCode'), on='PostalCode')
df3.shape
# Out:
# (103, 5)

# %% [markdown]
# Check whether it is the same as required by the question

# %%
dft = pd.DataFrame(columns=["PostalCode", "Borough", "Neighborhood", "Latitude", "Longitude"])

for pc in ["M5G", "M2H", "M4B", "M1J", "M4G", "M4M", "M1R", "M9V", "M9L", "M5V", "M1B", "M5A"]:
    dft = dft.append(df3[df3["PostalCode"]==pc], ignore_index=True)
    
dft
# Out:
#    PostalCode           Borough  \
# 0         M5G  Downtown Toronto
# 1         M2H        North York
# 2         M4B         East York
# 3         M1J       Scarborough
# 4         M4G         East York
# 5         M4M      East Toronto
# 6         M1R       Scarborough
# 7         M9V         Etobicoke
# 8         M9L        North York
# 9         M5V  Downtown Toronto
# 10        M1B       Scarborough
# 11        M5A  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 0                                  Central Bay Street  43.657952 -79.387383
# 1                                   Hillcrest Village  43.803762 -79.363452
# 2                     Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 3                                 Scarborough Village  43.744734 -79.239476
# 4                                             Leaside  43.709060 -79.363452
# 5                                     Studio District  43.659526 -79.340923
# 6                                   Maryvale, Wexford  43.750072 -79.295849
# 7   Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 8                                       Humber Summit  43.756303 -79.565963
# 9   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 10                                     Rouge, Malvern  43.806686 -79.194353
# 11                                       Harbourfront  43.654260 -79.360636

# %% [markdown]
# ## **PART 3**

# %% [markdown]
# Print the number of boroughs and postal codes

# %%
print('The dataframe has {} boroughs and {} postal codes.'.format(len(df3['Borough'].unique()),len(df3['PostalCode'].unique())))
print('The name of the boroughs are: ',df3['Borough'].unique())
# Out:
# The dataframe has 11 boroughs and 103 postal codes.
# The name of the boroughs are:  ['Scarborough' 'North York' 'East York' 'East Toronto' 'Central Toronto'
#  'Downtown Toronto' 'York' 'West Toronto' 'Mississauga' 'Etobicoke'
#  "Queen's Park"]

# %% [markdown]
# #### Create the DataFrame of Neighborhoods for our analysis

# %% [markdown]
# Lets work only with the boroughs that contain the word Toronto

# %%
dfN = df3[df3['Borough'].str.contains("Toronto")]
print('The new dataframe has {} neighborhoods'.format(len(dfN['Neighborhood'].unique())))
# Out:
# The new dataframe has 39 neighborhoods

# %% [markdown]
# Create a map with the postal codes' areas

# %%
location = Nominatim(user_agent = "foursquare_agent").geocode('Toronto')

map = folium.Map(location = [location.latitude, location.longitude], zoom_start = 12)

for lat, lng, label in zip(df3.Latitude, df3.Longitude, df3.PostalCode):
        folium.features.CircleMarker([lat, lng],radius=2.5,color='blue' ,popup=label).add_to(map)
for lat, lng, label in zip(dfN.Latitude, dfN.Longitude, dfN.PostalCode):
        folium.features.CircleMarker([lat, lng],radius=7.5,color='green',popup=label).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Define Foursquare credentials

# %%
CLIENT_ID = '5BE1CFT1DAZS0QY4L02YFE3312POUPPMMW3PTEMNBYU3UNPC'
CLIENT_SECRET = 'TTCGHPU30N3LWFLLCHWMOSDHQ1BBFVU2I53NRYUJNEZR3X0F'
VERSION = '20180604'

# %% [markdown]
# #### Create the DataFrame of Venues for our analysis

# %% [markdown]
# Let's get the top 100 venues of Toronto's neighborhoods inside a radius of 500m

# %%
LIMIT = 100
R = 500

venues_list = []

for NB, LT, LG in zip(dfN['Neighborhood'],dfN['Latitude'],dfN['Longitude']):
                    
    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, LT, LG, R, LIMIT)
            
    # make the GET request
    results = requests.get(url).json()["response"]['groups'][0]['items']
        
    # return only relevant information for each nearby venue
    venues_list.append([(NB,LT,LG,v['venue']['name'],v['venue']['location']['lat'],v['venue']['location']['lng'], v['venue']['categories'][0]['name']) for v in results])

dfV = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
dfV.columns = ['Neighborhood','Neighborhood Latitude','Neighborhood Longitude','Venue','Venue Latitude','Venue Longitude','Venue Category']
    
print('There are {} venues'.format(dfV.shape[0]))
# Out:
# There are 1702 venues

# %% [markdown]
# Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(dfV['Venue Category'].unique())))
# Out:
# There are 232 uniques categories.

# %% [markdown]
# ### One Hot Encoding

# %%
OHE = pd.get_dummies(dfV[['Venue Category']], prefix="", prefix_sep="") # one hot encoding
OHE['Neighbourhood'] = dfV['Neighborhood'] # add neighborhood column back to dataframe
fixed_columns = [OHE.columns[-1]] + list(OHE.columns[:-1]) # move neighborhood column to the first column
OHE = OHE[fixed_columns]

# %% [markdown]
# Group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
OHG = OHE.groupby('Neighbourhood').mean().reset_index()

# %% [markdown]
# Print each neighborhood along with the top 10 Most Common Venues

# %%
ntv = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(ntv):
    try:
        columns.append('{}{}'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th'.format(ind+1))

# create a new dataframe
NVS = pd.DataFrame(columns=columns)
NVS['Neighborhood'] = OHG['Neighbourhood']

for ind in np.arange(OHG.shape[0]):
    NVS.iloc[ind, 1:] = OHG.iloc[ind, :].iloc[1:].sort_values(ascending=False).index.values[0:ntv]

NVS
# Out:
#                                          Neighborhood               1st  \
# 0                            Adelaide, King, Richmond       Coffee Shop
# 1                                         Berczy Park       Coffee Shop
# 2        Brockton, Exhibition Place, Parkdale Village       Coffee Shop
# 3   Business Reply Mail Processing Centre 969 Eastern       Yoga Studio
# 4   CN Tower, Bathurst Quay, Island airport, Harbo...    Airport Lounge
# 5                         Cabbagetown, St. James Town       Coffee Shop
# 6                                  Central Bay Street       Coffee Shop
# 7           Chinatown, Grange Park, Kensington Market              Café
# 8                                            Christie     Grocery Store
# 9                                Church and Wellesley       Coffee Shop
# 10                     Commerce Court, Victoria Hotel       Coffee Shop
# 11                                         Davisville    Sandwich Place
# 12                                   Davisville North              Park
# 13  Deer Park, Forest Hill SE, Rathnelly, South Hi...               Pub
# 14           Design Exchange, Toronto Dominion Centre       Coffee Shop
# 15                       Dovercourt Village, Dufferin          Pharmacy
# 16             First Canadian Place, Underground city       Coffee Shop
# 17                Forest Hill North, Forest Hill West     Jewelry Store
# 18                     Harbord, University of Toronto              Café
# 19                                       Harbourfront       Coffee Shop
# 20  Harbourfront East, Toronto Islands, Union Station       Coffee Shop
# 21                      High Park, The Junction South              Café
# 22                                      Lawrence Park              Park
# 23                           Little Portugal, Trinity               Bar
# 24                        Moore Park, Summerhill East               Gym
# 25                                 North Toronto West       Coffee Shop
# 26                             Parkdale, Roncesvalles         Gift Shop
# 27                                       Queen's Park       Coffee Shop
# 28                                           Rosedale              Park
# 29                                           Roselawn            Garden
# 30                                 Runnymede, Swansea       Pizza Place
# 31                           Ryerson, Garden District       Coffee Shop
# 32                                     St. James Town       Coffee Shop
# 33                    Stn A PO Boxes 25 The Esplanade       Coffee Shop
# 34                                    Studio District              Café
# 35                The Annex, North Midtown, Yorkville    Sandwich Place
# 36                                        The Beaches              Park
# 37                     The Beaches West, India Bazaar              Park
# 38                       The Danforth West, Riverdale  Greek Restaurant
#
#                       2nd                          3rd                   4th  \
# 0                     Bar                   Steakhouse                  Café
# 1            Cocktail Bar                         Café            Steakhouse
# 2          Breakfast Spot                         Café                Bakery
# 3           Auto Workshop                   Comic Shop                  Park
# 4         Airport Service             Airport Terminal              Boutique
# 5      Italian Restaurant                         Park           Pizza Place
# 6                    Café               Ice Cream Shop    Italian Restaurant
# 7   Vietnamese Restaurant           Chinese Restaurant   Dumpling Restaurant
# 8                    Café                         Park           Candy Store
# 9     Japanese Restaurant                   Restaurant      Sushi Restaurant
# 10                   Café                        Hotel            Restaurant
# 11           Dessert Shop           Italian Restaurant           Coffee Shop
# 12         Sandwich Place             Department Store     Food & Drink Shop
# 13            Coffee Shop          American Restaurant            Restaurant
# 14                   Café                        Hotel            Restaurant
# 15                 Bakery                Grocery Store           Music Venue
# 16                   Café                   Restaurant            Steakhouse
# 17                  Trail           Mexican Restaurant      Sushi Restaurant
# 18         Sandwich Place                   Restaurant   Japanese Restaurant
# 19                   Park                       Bakery                   Pub
# 20               Aquarium                         Café    Italian Restaurant
# 21     Mexican Restaurant                          Bar       Thai Restaurant
# 22            Swim School                     Bus Line  Fast Food Restaurant
# 23             Restaurant                  Men's Store           Coffee Shop
# 24             Playground                 Tennis Court           Yoga Studio
# 25    Sporting Goods Shop         Fast Food Restaurant                 Diner
# 26              Bookstore  Eastern European Restaurant            Restaurant
# 27                   Park                          Gym             Nightclub
# 28             Playground                        Trail      Department Store
# 29            Yoga Studio                 Dessert Shop    Falafel Restaurant
# 30            Coffee Shop                         Café              Tea Room
# 31         Clothing Store                         Café        Cosmetics Shop
# 32                   Café                   Restaurant                 Hotel
# 33                   Café           Seafood Restaurant   Japanese Restaurant
# 34            Coffee Shop                    Gastropub               Brewery
# 35                   Café                  Coffee Shop                  Park
# 36      Health Food Store                 Neighborhood                   Pub
# 37          Movie Theater                   Steakhouse      Sushi Restaurant
# 38            Coffee Shop           Italian Restaurant        Ice Cream Shop
#
#                               5th                        6th  \
# 0                      Restaurant           Asian Restaurant
# 1                          Bakery                Cheese Shop
# 2                   Grocery Store                    Stadium
# 3                     Pizza Place           Recording Studio
# 4                 Harbor / Marina              Boat or Ferry
# 5                          Bakery                 Restaurant
# 6                  Sandwich Place         Chinese Restaurant
# 7   Vegetarian / Vegan Restaurant                Coffee Shop
# 8                      Restaurant                      Diner
# 9                         Gay Bar                       Café
# 10                            Gym                 Steakhouse
# 11                            Gym                       Café
# 12                          Hotel                        Gym
# 13            Fried Chicken Joint                 Sports Bar
# 14                     Steakhouse                  Gastropub
# 15                        Brewery                       Café
# 16                          Hotel           Asian Restaurant
# 17                    Yoga Studio         Dim Sum Restaurant
# 18                      Bookstore                        Bar
# 19                 Breakfast Spot                 Restaurant
# 20                          Hotel                 Restaurant
# 21                  Grocery Store        Fried Chicken Joint
# 22             Falafel Restaurant                Event Space
# 23               Asian Restaurant      Vietnamese Restaurant
# 24                   Dessert Shop                Event Space
# 25             Mexican Restaurant               Dessert Shop
# 26                        Dog Run               Dessert Shop
# 27                 Sandwich Place                Salad Place
# 28                    Event Space       Ethiopian Restaurant
# 29                    Event Space       Ethiopian Restaurant
# 30               Sushi Restaurant         Italian Restaurant
# 31           Fast Food Restaurant  Middle Eastern Restaurant
# 32                 Breakfast Spot               Cocktail Bar
# 33                     Restaurant                   Beer Bar
# 34                         Bakery         Italian Restaurant
# 35                          Plaza                Flower Shop
# 36                          Trail        Dumpling Restaurant
# 37              Fish & Chips Shop                    Brewery
# 38         Furniture / Home Store                Yoga Studio
#
#                               7th                          8th  \
# 0                  Breakfast Spot              Thai Restaurant
# 1                        Beer Bar               Farmers Market
# 2                   Burrito Place                   Restaurant
# 3                      Restaurant                Burrito Place
# 4             Rental Car Location                          Bar
# 5                            Café                          Pub
# 6                    Burger Joint          Japanese Restaurant
# 7                             Bar           Mexican Restaurant
# 8              Italian Restaurant                  Gas Station
# 9                             Gym                        Hotel
# 10                  Deli / Bodega           Seafood Restaurant
# 11               Sushi Restaurant                  Pizza Place
# 12                 Breakfast Spot            Electronics Store
# 13               Sushi Restaurant                  Pizza Place
# 14             Seafood Restaurant           Italian Restaurant
# 15                    Supermarket                          Bar
# 16                      Gastropub           Seafood Restaurant
# 17                    Event Space         Ethiopian Restaurant
# 18                         Bakery            French Restaurant
# 19                           Café           Mexican Restaurant
# 20                        Brewery               Scenic Lookout
# 21           Fast Food Restaurant                    Bookstore
# 22           Ethiopian Restaurant            Electronics Store
# 23                           Café                  Pizza Place
# 24           Ethiopian Restaurant            Electronics Store
# 25                           Park               Clothing Store
# 26                  Movie Theater           Italian Restaurant
# 27                   Burger Joint                Burrito Place
# 28              Electronics Store  Eastern European Restaurant
# 29              Electronics Store  Eastern European Restaurant
# 30  Vegetarian / Vegan Restaurant                          Bar
# 31                         Bakery          Japanese Restaurant
# 32                       Beer Bar               Cosmetics Shop
# 33                          Hotel           Italian Restaurant
# 34            American Restaurant                  Yoga Studio
# 35                            Pub    Middle Eastern Restaurant
# 36                     Donut Shop             Doner Restaurant
# 37                            Pub           Italian Restaurant
# 38        Fruit & Vegetable Store                   Restaurant
#
#                             9th                         10th
# 0                         Hotel           Seafood Restaurant
# 1            Seafood Restaurant                       Bistro
# 2                  Climbing Gym                    Pet Store
# 3                       Brewery           Light Rail Station
# 4                         Plane                  Coffee Shop
# 5                 Grocery Store                        Diner
# 6                     Juice Bar                          Bar
# 7                 Grocery Store                 Burger Joint
# 8                    Baby Store                    Nightclub
# 9      Mediterranean Restaurant         Fast Food Restaurant
# 10                    Gastropub              Thai Restaurant
# 11                     Pharmacy           Seafood Restaurant
# 12  Eastern European Restaurant          Dumpling Restaurant
# 13                  Supermarket                 Liquor Store
# 14                          Bar                Deli / Bodega
# 15                         Bank    Middle Eastern Restaurant
# 16                          Bar                          Gym
# 17            Electronics Store  Eastern European Restaurant
# 18                          Pub                   Beer Store
# 19               Farmers Market                  Event Space
# 20          Fried Chicken Joint               History Museum
# 21           Italian Restaurant                    Speakeasy
# 22  Eastern European Restaurant          Dumpling Restaurant
# 23                  Yoga Studio                       Bistro
# 24  Eastern European Restaurant          Dumpling Restaurant
# 25           Chinese Restaurant                         Café
# 26             Cuban Restaurant                  Coffee Shop
# 27                         Café        Portuguese Restaurant
# 28          Dumpling Restaurant                   Donut Shop
# 29          Dumpling Restaurant                   Donut Shop
# 30                    Gastropub                 Dessert Shop
# 31                   Restaurant              Bubble Tea Shop
# 32           Italian Restaurant               Clothing Store
# 33                 Cocktail Bar               Breakfast Spot
# 34      Comfort Food Restaurant               Sandwich Place
# 35            Indian Restaurant               History Museum
# 36             Department Store  Eastern European Restaurant
# 37         Fast Food Restaurant                 Liquor Store
# 38                          Pub                  Pizza Place

# %% [markdown]
# #### Clustering

# %% [markdown]
# Run k-means to cluster the Toronto areas into 5 clusters

# %%
kclusters = 5 # set number of clusters

OHC = OHG.drop('Neighbourhood', 1)

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(OHC) # run k-means clustering

# %% [markdown]
# Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood

# %%
NVS.insert(0, 'Cluster Labels', kmeans.labels_) # add clustering labels

dfM = dfN.join(NVS.set_index('Neighborhood'), on='Neighborhood') # merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood

dfM
# Out:
#    PostalCode           Borough  \
# 37        M4E      East Toronto
# 41        M4K      East Toronto
# 42        M4L      East Toronto
# 43        M4M      East Toronto
# 44        M4N   Central Toronto
# 45        M4P   Central Toronto
# 46        M4R   Central Toronto
# 47        M4S   Central Toronto
# 48        M4T   Central Toronto
# 49        M4V   Central Toronto
# 50        M4W  Downtown Toronto
# 51        M4X  Downtown Toronto
# 52        M4Y  Downtown Toronto
# 53        M5A  Downtown Toronto
# 54        M5B  Downtown Toronto
# 55        M5C  Downtown Toronto
# 56        M5E  Downtown Toronto
# 57        M5G  Downtown Toronto
# 58        M5H  Downtown Toronto
# 59        M5J  Downtown Toronto
# 60        M5K  Downtown Toronto
# 61        M5L  Downtown Toronto
# 63        M5N   Central Toronto
# 64        M5P   Central Toronto
# 65        M5R   Central Toronto
# 66        M5S  Downtown Toronto
# 67        M5T  Downtown Toronto
# 68        M5V  Downtown Toronto
# 69        M5W  Downtown Toronto
# 70        M5X  Downtown Toronto
# 75        M6G  Downtown Toronto
# 76        M6H      West Toronto
# 77        M6J      West Toronto
# 78        M6K      West Toronto
# 82        M6P      West Toronto
# 83        M6R      West Toronto
# 84        M6S      West Toronto
# 85        M7A  Downtown Toronto
# 87        M7Y      East Toronto
#
#                                          Neighborhood   Latitude  Longitude  \
# 37                                        The Beaches  43.676357 -79.293031
# 41                       The Danforth West, Riverdale  43.679557 -79.352188
# 42                     The Beaches West, India Bazaar  43.668999 -79.315572
# 43                                    Studio District  43.659526 -79.340923
# 44                                      Lawrence Park  43.728020 -79.388790
# 45                                   Davisville North  43.712751 -79.390197
# 46                                 North Toronto West  43.715383 -79.405678
# 47                                         Davisville  43.704324 -79.388790
# 48                        Moore Park, Summerhill East  43.689574 -79.383160
# 49  Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 50                                           Rosedale  43.679563 -79.377529
# 51                        Cabbagetown, St. James Town  43.667967 -79.367675
# 52                               Church and Wellesley  43.665860 -79.383160
# 53                                       Harbourfront  43.654260 -79.360636
# 54                           Ryerson, Garden District  43.657162 -79.378937
# 55                                     St. James Town  43.651494 -79.375418
# 56                                        Berczy Park  43.644771 -79.373306
# 57                                 Central Bay Street  43.657952 -79.387383
# 58                           Adelaide, King, Richmond  43.650571 -79.384568
# 59  Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 60           Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 61                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 63                                           Roselawn  43.711695 -79.416936
# 64                Forest Hill North, Forest Hill West  43.696948 -79.411307
# 65                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 66                     Harbord, University of Toronto  43.662696 -79.400049
# 67          Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 68  CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 69                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 70             First Canadian Place, Underground city  43.648429 -79.382280
# 75                                           Christie  43.669542 -79.422564
# 76                       Dovercourt Village, Dufferin  43.669005 -79.442259
# 77                           Little Portugal, Trinity  43.647927 -79.419750
# 78       Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 82                      High Park, The Junction South  43.661608 -79.464763
# 83                             Parkdale, Roncesvalles  43.648960 -79.456325
# 84                                 Runnymede, Swansea  43.651571 -79.484450
# 85                                       Queen's Park  43.662301 -79.389494
# 87  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
#
#     Cluster Labels               1st                    2nd  \
# 37               4              Park      Health Food Store
# 41               0  Greek Restaurant            Coffee Shop
# 42               0              Park          Movie Theater
# 43               0              Café            Coffee Shop
# 44               3              Park            Swim School
# 45               0              Park         Sandwich Place
# 46               0       Coffee Shop    Sporting Goods Shop
# 47               0    Sandwich Place           Dessert Shop
# 48               2               Gym             Playground
# 49               0               Pub            Coffee Shop
# 50               4              Park             Playground
# 51               0       Coffee Shop     Italian Restaurant
# 52               0       Coffee Shop    Japanese Restaurant
# 53               0       Coffee Shop                   Park
# 54               0       Coffee Shop         Clothing Store
# 55               0       Coffee Shop                   Café
# 56               0       Coffee Shop           Cocktail Bar
# 57               0       Coffee Shop                   Café
# 58               0       Coffee Shop                    Bar
# 59               0       Coffee Shop               Aquarium
# 60               0       Coffee Shop                   Café
# 61               0       Coffee Shop                   Café
# 63               1            Garden            Yoga Studio
# 64               0     Jewelry Store                  Trail
# 65               0    Sandwich Place                   Café
# 66               0              Café         Sandwich Place
# 67               0              Café  Vietnamese Restaurant
# 68               0    Airport Lounge        Airport Service
# 69               0       Coffee Shop                   Café
# 70               0       Coffee Shop                   Café
# 75               0     Grocery Store                   Café
# 76               0          Pharmacy                 Bakery
# 77               0               Bar             Restaurant
# 78               0       Coffee Shop         Breakfast Spot
# 82               0              Café     Mexican Restaurant
# 83               0         Gift Shop              Bookstore
# 84               0       Pizza Place            Coffee Shop
# 85               0       Coffee Shop                   Park
# 87               0       Yoga Studio          Auto Workshop
#
#                             3rd                   4th  \
# 37                 Neighborhood                   Pub
# 41           Italian Restaurant        Ice Cream Shop
# 42                   Steakhouse      Sushi Restaurant
# 43                    Gastropub               Brewery
# 44                     Bus Line  Fast Food Restaurant
# 45             Department Store     Food & Drink Shop
# 46         Fast Food Restaurant                 Diner
# 47           Italian Restaurant           Coffee Shop
# 48                 Tennis Court           Yoga Studio
# 49          American Restaurant            Restaurant
# 50                        Trail      Department Store
# 51                         Park           Pizza Place
# 52                   Restaurant      Sushi Restaurant
# 53                       Bakery                   Pub
# 54                         Café        Cosmetics Shop
# 55                   Restaurant                 Hotel
# 56                         Café            Steakhouse
# 57               Ice Cream Shop    Italian Restaurant
# 58                   Steakhouse                  Café
# 59                         Café    Italian Restaurant
# 60                        Hotel            Restaurant
# 61                        Hotel            Restaurant
# 63                 Dessert Shop    Falafel Restaurant
# 64           Mexican Restaurant      Sushi Restaurant
# 65                  Coffee Shop                  Park
# 66                   Restaurant   Japanese Restaurant
# 67           Chinese Restaurant   Dumpling Restaurant
# 68             Airport Terminal              Boutique
# 69           Seafood Restaurant   Japanese Restaurant
# 70                   Restaurant            Steakhouse
# 75                         Park           Candy Store
# 76                Grocery Store           Music Venue
# 77                  Men's Store           Coffee Shop
# 78                         Café                Bakery
# 82                          Bar       Thai Restaurant
# 83  Eastern European Restaurant            Restaurant
# 84                         Café              Tea Room
# 85                          Gym             Nightclub
# 87                   Comic Shop                  Park
#
#                               5th                        6th  \
# 37                          Trail        Dumpling Restaurant
# 41         Furniture / Home Store                Yoga Studio
# 42              Fish & Chips Shop                    Brewery
# 43                         Bakery         Italian Restaurant
# 44             Falafel Restaurant                Event Space
# 45                          Hotel                        Gym
# 46             Mexican Restaurant               Dessert Shop
# 47                            Gym                       Café
# 48                   Dessert Shop                Event Space
# 49            Fried Chicken Joint                 Sports Bar
# 50                    Event Space       Ethiopian Restaurant
# 51                         Bakery                 Restaurant
# 52                        Gay Bar                       Café
# 53                 Breakfast Spot                 Restaurant
# 54           Fast Food Restaurant  Middle Eastern Restaurant
# 55                 Breakfast Spot               Cocktail Bar
# 56                         Bakery                Cheese Shop
# 57                 Sandwich Place         Chinese Restaurant
# 58                     Restaurant           Asian Restaurant
# 59                          Hotel                 Restaurant
# 60                     Steakhouse                  Gastropub
# 61                            Gym                 Steakhouse
# 63                    Event Space       Ethiopian Restaurant
# 64                    Yoga Studio         Dim Sum Restaurant
# 65                          Plaza                Flower Shop
# 66                      Bookstore                        Bar
# 67  Vegetarian / Vegan Restaurant                Coffee Shop
# 68                Harbor / Marina              Boat or Ferry
# 69                     Restaurant                   Beer Bar
# 70                          Hotel           Asian Restaurant
# 75                     Restaurant                      Diner
# 76                        Brewery                       Café
# 77               Asian Restaurant      Vietnamese Restaurant
# 78                  Grocery Store                    Stadium
# 82                  Grocery Store        Fried Chicken Joint
# 83                        Dog Run               Dessert Shop
# 84               Sushi Restaurant         Italian Restaurant
# 85                 Sandwich Place                Salad Place
# 87                    Pizza Place           Recording Studio
#
#                               7th                          8th  \
# 37                     Donut Shop             Doner Restaurant
# 41        Fruit & Vegetable Store                   Restaurant
# 42                            Pub           Italian Restaurant
# 43            American Restaurant                  Yoga Studio
# 44           Ethiopian Restaurant            Electronics Store
# 45                 Breakfast Spot            Electronics Store
# 46                           Park               Clothing Store
# 47               Sushi Restaurant                  Pizza Place
# 48           Ethiopian Restaurant            Electronics Store
# 49               Sushi Restaurant                  Pizza Place
# 50              Electronics Store  Eastern European Restaurant
# 51                           Café                          Pub
# 52                            Gym                        Hotel
# 53                           Café           Mexican Restaurant
# 54                         Bakery          Japanese Restaurant
# 55                       Beer Bar               Cosmetics Shop
# 56                       Beer Bar               Farmers Market
# 57                   Burger Joint          Japanese Restaurant
# 58                 Breakfast Spot              Thai Restaurant
# 59                        Brewery               Scenic Lookout
# 60             Seafood Restaurant           Italian Restaurant
# 61                  Deli / Bodega           Seafood Restaurant
# 63              Electronics Store  Eastern European Restaurant
# 64                    Event Space         Ethiopian Restaurant
# 65                            Pub    Middle Eastern Restaurant
# 66                         Bakery            French Restaurant
# 67                            Bar           Mexican Restaurant
# 68            Rental Car Location                          Bar
# 69                          Hotel           Italian Restaurant
# 70                      Gastropub           Seafood Restaurant
# 75             Italian Restaurant                  Gas Station
# 76                    Supermarket                          Bar
# 77                           Café                  Pizza Place
# 78                  Burrito Place                   Restaurant
# 82           Fast Food Restaurant                    Bookstore
# 83                  Movie Theater           Italian Restaurant
# 84  Vegetarian / Vegan Restaurant                          Bar
# 85                   Burger Joint                Burrito Place
# 87                     Restaurant                Burrito Place
#
#                             9th                         10th
# 37             Department Store  Eastern European Restaurant
# 41                          Pub                  Pizza Place
# 42         Fast Food Restaurant                 Liquor Store
# 43      Comfort Food Restaurant               Sandwich Place
# 44  Eastern European Restaurant          Dumpling Restaurant
# 45  Eastern European Restaurant          Dumpling Restaurant
# 46           Chinese Restaurant                         Café
# 47                     Pharmacy           Seafood Restaurant
# 48  Eastern European Restaurant          Dumpling Restaurant
# 49                  Supermarket                 Liquor Store
# 50          Dumpling Restaurant                   Donut Shop
# 51                Grocery Store                        Diner
# 52     Mediterranean Restaurant         Fast Food Restaurant
# 53               Farmers Market                  Event Space
# 54                   Restaurant              Bubble Tea Shop
# 55           Italian Restaurant               Clothing Store
# 56           Seafood Restaurant                       Bistro
# 57                    Juice Bar                          Bar
# 58                        Hotel           Seafood Restaurant
# 59          Fried Chicken Joint               History Museum
# 60                          Bar                Deli / Bodega
# 61                    Gastropub              Thai Restaurant
# 63          Dumpling Restaurant                   Donut Shop
# 64            Electronics Store  Eastern European Restaurant
# 65            Indian Restaurant               History Museum
# 66                          Pub                   Beer Store
# 67                Grocery Store                 Burger Joint
# 68                        Plane                  Coffee Shop
# 69                 Cocktail Bar               Breakfast Spot
# 70                          Bar                          Gym
# 75                   Baby Store                    Nightclub
# 76                         Bank    Middle Eastern Restaurant
# 77                  Yoga Studio                       Bistro
# 78                 Climbing Gym                    Pet Store
# 82           Italian Restaurant                    Speakeasy
# 83             Cuban Restaurant                  Coffee Shop
# 84                    Gastropub                 Dessert Shop
# 85                         Café        Portuguese Restaurant
# 87                      Brewery           Light Rail Station

# %%
# create map
map_clusters = folium.Map(location=[LT,LG], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(dfM['Latitude'], dfM['Longitude'], dfM['Neighborhood'], dfM['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
